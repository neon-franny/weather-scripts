# %%
# !mamba install pandas
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.405 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.5    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.3   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge

# %%
# !mamba install odfpy
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, odfpy
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.084 seconds
#   Name        Version  Build         Channel
# --------------------------------------------------
# + defusedxml  0.7.1    pyhd8ed1ab_0  conda-forge
# + odfpy       1.4.1    pyhd8ed1ab_1  conda-forge

# %%
import pandas as pd
from datetime import date, timedelta

# %%
df = pd.read_excel('weather_src_ods.ods', engine='odf')
print(df.head())
# Out:
#                   Осадки  Днем       Населенные пункты
# 0  переменная облачность    28                    Чита
# 1  переменная облачность    29  Петровск-Забайкальский
# 2  переменная облачность    29                   Хилок
# 3  переменная облачность    29           Красный Чикой
# 4  переменная облачность    29                   Улеты

# %%
months = {
    1: 'января', 2: 'февраля', 3: 'марта', 4: 'апреля',
    5: 'мая', 6: 'июня', 7: 'июля', 8: 'августа',
    9: 'сентября', 10: 'октября', 11: 'ноября', 12: 'декабря'
}

#df = df.drop(columns=['Ночью'])
today = date.today() + timedelta(days=1)
d_date = today.strftime("%d").replace('0', '')
m_date = f'{months[today.month]}'
df_len = len(df)

for a in range(df_len - 1):
    city = str(df.iloc[a, 2])
    temp = '+' + str(df.iloc[a, 1])
    rainfall = str(df.iloc[a, 0])
    w_str = '   ' + d_date + ' ' + m_date + ': ' + city + '  ' + temp + '  ' + rainfall +'\r\n'
    print('   ' + d_date + ' ' + m_date + ': ' + city + '  ' + temp + '  ' + rainfall +'\r\n')
    with open("output.csv", "a") as file:
        file.write(w_str)
# Out:
#    5 августа: Чита  +28  переменная облачность
#
#    5 августа: Петровск-Забайкальский  +29  переменная облачность
#
#    5 августа: Хилок  +29  переменная облачность
#
#    5 августа: Красный Чикой  +29  переменная облачность
#
#    5 августа: Улеты  +29  переменная облачность
#
#    5 августа: Карымское  +29  переменная облачность
#
#    5 августа: Кыра  +28  возможен дождь
#
#    5 августа: Акша  +29  переменная облачность
#
#    5 августа: Агинское  +30  переменная облачность
#
#    5 августа: Дульдурга  +30  переменная облачность
#
#    5 августа: Могойтуй  +30  переменная облачность
#
#    5 августа: Нижний Цасучей  +29  переменная облачность
#
#    5 августа: Оловянная  +30  возможен дождь
#
#    5 августа: Борзя  +30  переменная облачность
#
#    5 августа: Забайкальск  +30  переменная облачность
#
#    5 августа: Краснокаменск  +31  переменная облачность
#
#    5 августа: Приаргунск  +30  переменная облачность
#
#    5 августа: Калга  +30  переменная облачность
#
#    5 августа: Нерчинский Завод  +29  возможен дождь
#
#    5 августа: Александровский Завод  +27  переменная облачность
#
#    5 августа: Газимурский Завод  +29  переменная облачность
#
#    5 августа: Шилка  +30  переменная облачность
#
#    5 августа: Нерчинск  +31  переменная облачность
#
#    5 августа: Сретенск  +30  переменная облачность
#
#    5 августа: Балей  +30  переменная облачность
#
#    5 августа: Чернышевск  +30  небольшой дождь
#
#    5 августа: Шелопугино  +28  переменная облачность
#
#    5 августа: Могоча  +29  переменная облачность
#
#    5 августа: Верх-Усугли  +30  возможен дождь
#
#    5 августа: Тупик  +27  переменная облачность

# %%
city = str(df.iloc[df_len - 1, 2])
temp = '+' + str(df.iloc[df_len - 1, 1])
rainfall = str(df.iloc[df_len - 1, 0])
w_str = '   ' + d_date + ' ' + m_date + ': ' + city + '  ' + temp + '  ' + rainfall

with open("output.csv", "a") as file:
    file.write(w_str)
# Out:
#    5 августа: Чара  +24  переменная облачность
